# %%
import pandas as pd

# %%
path = 'https://raw.githubusercontent.com/jherberg462/python-api-challenge/master/WeatherPy/output/CityData.csv'
df = pd.read_csv(path)
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#          City Name Country  Longitude  Latitude  Maximum Tempeture  Humidity  \
# 0    Mar del Plata      AR     -67.52    -46.43              54.57        32
# 1          Mataura      NZ     168.86    -46.19              57.99        82
# 2           Faanui      PF    -151.75    -16.48              80.37        66
# 3       Kaitangata      NZ     169.85    -46.28              52.12        89
# 4  Bambous Virieux      MU      57.76    -20.34              75.99        94
#
#    Cloudiness(%)  Wind Speed              Date
# 0             41       21.30  October 26, 2019
# 1            100        3.00  October 26, 2019
# 2             36        8.03  October 26, 2019
# 3            100        5.82  October 26, 2019
# 4             40        3.36  October 26, 2019

# %%
html = df.to_html('table.html')

# %%
html.replace('\n', '')
html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City Name</th>\n      <th>Country</th>\n      <th>Longitude</th>\n      <th>Latitude</th>\n      <th>Maximum Tempeture</th>\n      <th>Humidity</th>\n      <th>Cloudiness(%)</th>\n      <th>Wind Speed</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Mar del Plata</td>\n      <td>AR</td>\n      <td>-67.52</td>\n      <td>-46.43</td>\n      <td>54.57</td>\n      <td>32</td>\n      <td>41</td>\n      <td>21.30</td>\n      <td>October 26, 2019</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Mataura</td>\n      <td>NZ</td>\n      <td>168.86</td>\n      <td>-46.19</td>\n      <td>57.99</td>\n      <td>82</td>\n      <td>100</td>\n      <td>3.00</td>\n      <td>October 26, 2019</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Faanui</td>\n      <td>PF</td>\n      <td>-151.75</td>\n      <td>-16.48</td>\n      <td>80.
# ...
